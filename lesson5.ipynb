# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import load_breast_cancer

#乳がんに関するデータセット
cancer = load_breast_cancer()


df = pd.DataFrame(cancer.data,columns=cancer.feature_names )
df["Cancer"] = cancer.target 
display(df)
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0          17.99         10.38          122.80     1001.0          0.11840
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
# ...

# %%
#ロジスティック回帰
#いくつかの二組を説明変数として学習

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score

for p in [["fractal dimension error","mean compactness"],["fractal dimension error","mean texture"],["mean radius","mean compactness"],["mean radius","mean texture"]]:
    sc = StandardScaler()
    df2 = pd.DataFrame(sc.fit_transform(df[[p[0],p[1]]]))
    df2.index = df.index
    
    X = df2 # 説明変数
    Y = df['Cancer'] # 目的変数
    X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2, random_state = 0) # 80%のデータを学習データに、20%を検証データにする
    lr = LogisticRegression() # ロジスティック回帰モデルのインスタンスを作成
    lr.fit(X_train, Y_train) # ロジスティック回帰モデルの重みを学習
    
    Y_pred = lr.predict(X_test)
    print(p[0],p[1],'f1 score = ', f1_score(y_true=Y_test, y_pred=Y_pred))
# Out:
# fractal dimension error mean compactness f1 score =  0.8194444444444445
# fractal dimension error mean texture f1 score =  0.7651006711409395
# mean radius mean compactness f1 score =  0.8985507246376812
# mean radius mean texture f1 score =  0.9117647058823529

# %%
#"mean radius"と"mean texture"
fig = plt.figure(figsize=(8,8),dpi=100)
sc = StandardScaler()
x1 = "mean radius"
x2 = "mean texture"
plt.xlabel(x1)
plt.ylabel(x2)
plt.xlim(-3.0,5.0)
plt.ylim(-3.0,5.0)

df[x1+"_std"] = sc.fit_transform(np.array([df[x1]]).T)
df[x2+"_std"] = sc.fit_transform(np.array([df[x2]]).T)

plt.scatter(df2[df["Cancer"]==0][x1+"_std"],df[df["Cancer"]==0][x2+"_std"],label="Not Cancer")
plt.scatter(df2[df["Cancer"]==1][x1+"_std"],df[df["Cancer"]==1][x2+"_std"],label="Cancer")

x1 = np.linspace(-3, 5, 100)
y = calc(x1,lr.intercept_,lr.coef_[0][0],lr.coef_[0][1])
plt.plot(x1, y,color='green')
plt.legend()

plt.show()

# %%
#mean textureとmean compactnessに関しては、fractal dimension errorよりmean radiousの方が相性がよく、学習した結果いいF値が出ている。
#またその中でもmean textureの方がいい結果が出ている
